# %% [markdown]
# # Data Preprocessing
#
# This notebook cleans, tokenizes and augments data

# %%
import pandas as pd
import re
import os
from dotenv import load_dotenv
from tqdm import tqdm
import random
import numpy as np
import warnings

# Tokenization
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktParameters

# Data Augmentation
import openai

# Burrow's Delta Score
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import CountVectorizer
from scipy.spatial.distance import cityblock  # Burrows' Delta uses Manhattan distance
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hadrienstrichard/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/hadrienstrichard/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# ## Cleaning and tokenizing

# %%
# Load initial data

texts = pd.read_parquet('../Data/excerpts_df.parquet')
final_authors = pd.read_csv('../Data/final_authors.csv')

# %%
# Basic cleaning function tailored for stylometry (preserving punctuation, no lemmatization)
def clean_text(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+|https\S+", '', text)  # remove URLs
    text = re.sub(r'\S+@\S+', '', text)  # remove emails
    text = re.sub(r'\d+', '', text)  # remove digits
    text = re.sub(r'\s+', ' ', text)  # normalize whitespace
    text = re.sub(r'[“”«»]', '"', text)  # normalize quotes
    text = re.sub(r"[’]", "'", text)  # normalize apostrophes
    return text.strip()

# %%
# Apply cleaning
texts['Cleaned_Text'] = texts['Excerpt_Text'].apply(clean_text)

# %%
# Display first 3 cleaned text for verification
pd.set_option('display.max_colwidth', None)
print(texts['Cleaned_Text'][:3])
# Out:
# index
# 0                                                                              n'est souvent déterminée que par un mot. en ce point même, cependant, il n'a fait que se conformer au caprice piquant de la nature, qui se joue à nous faire parcourir dans la durée d'un seul rêve, plusieurs fois interrompu par des épisodes étrangers à son objet, tous les développements d'une action régulière, complète et plus ou moins vraisemblable. les personnes qui ont lu apulée s'apercevront facilement que la fable du premier livre de l'_âne d'or_ de cet ingénieux conteur a beaucoup de rapports avec celle-ci, et qu'elles se ressemblent par le fond presque autant qu'elles diffèrent par la forme. l'auteur paraît même avoir affecté de solliciter ce rapprochement en conservant à son principal personnage le nom de lucius. le récit du philosophe de madaure et celui du prêtre dalmate, cité par fortis, tome i, page , ont en effet une origine commune dans les chants traditionnels d'une contrée qu'apulée avait curieusement visitée, mais dont il a dédaigné de retracer le caractère, ce qui n'empêche pas qu'apulée ne soit un des écrivains les plus romantiques des temps anciens. il florissait à l'époque même qui sépare les âges du goût des âges de l'imagination. je dois avouer en finissant que, si j'avais apprécié les difficultés de cette traduction avant de l'entreprendre, je ne m'en serais jamais occupé. séduit par l'effet général du poème sans me rendre compte des combinaisons qui le produisaient, j'en avais attribué le mérite à la composition qui est cependant tout à fait nulle, et dont le faible intérêt ne soutiendrait pas longtemps l'attention, si l'auteur ne l'avait relevé par l'emploi des prestiges d'une imagination qui étonne, et surtout par la hardiesse incroyable d'un style qui ne cesse jamais cependant d'être élevé, pittoresque, harmonieux. voilà précisément ce qu'il ne m'était pas donné de reproduire, et ce que je n'aurais pu essayer de faire passer dans notre langue sans une présomption ridicule. certain que les lecteurs qui connaissent l'ouvrage original ne verront dans cette faible copie qu'une tentative impuissante, j'avais du moins à coeur qu'ils ne crussent pas y voir l'effort trompé d'une vanité malheureuse. j'ai en littérature des juges si sévèrement inflexibles et des amis si religieusement impartiaux, que je suis persuadé d'avance que cette explication ne sera pas inutile pour les uns et pour les autres. sur des sujets nouveaux faisons des vers antiques, a dit andré chénier. cette idée me préoccupait singulièrement dans ma jeunesse; et il faut dire, pour expliquer mes inductions et pour les excuser, que j'étais seul, dans ma jeunesse, à pressentir l'infaillible avènement d'une littérature nouvelle. pour le génie, ce pouvait être une révélation. pour moi, ce n'était qu'un tourment. je savais bien que les sujets n'étaient pas épuisés, et qu'il restait encore des domaines immenses à exploiter à l'imagination; mais je le savais obscurément, à la manière des hommes médiocres, et je louvoyais de loin sur les parages de l'amérique, sans m'apercevoir qu'il y avait là un monde. j'attendais qu'une voix aimée criât: terre! une chose m'avait frappé: c'est qu'à la fin de toutes les littératures, l'invention semblait s'enrichir en proportion des pertes du goût, et que les écrivains en qui elle surgissait, toute neuve et toute brillante, retenus par quelque étrange pudeur, n'avaient jamais osé la livrer à la multitude que sous un masque de cynisme et de dérision, comme la folie des joies populaires ou la ménade des bacchanales. ceci est le signalement distinctif des génies trigémeaux de lucien, d'apulée et de voltaire. si on cherche maintenant quelle était l'âme de cette création des temps achevés, on la trouvera dans la fantaisie. les grands hommes des vieux peuples retournent comme les vieillards aux jeux des petits enfants, en affectant de les dédaigner devant les sages; mais c'est là qu'ils laissent déborder en riant tout ce que la nature leur avai ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       le reste ne me regarde point. j'ai dit de qui était la fable: sauf quelques phrases de transition, tout appartient à homère, à théocrite, à virgile, à catulle, à stace, à lucien, à dante, à shakespeare, à milton. je ne lisais pas autre chose. le défaut criant de smarra était donc de paraître ce qu'il était réellement, une étude, un centon, un pastiche des classiques, le plus mauvais volumen de l'école d'alexandrie échappé à l'incendie de la bibliothèque des ptolémées. personne ne s'en avisa. devineriez-vous ce qu'on fit de smarra, de cette fiction d'apulée, peut-être gauchement parfumée des roses d'anacréon? oh! livre studieux, livre méticuleux, livre d'innocence et de pudeur scolaire, livre écrit sous l'inspiration de l'antiquité la plus pure! on en fit un livre romantique! et henri estienne, scapula et schrevelius ne se levèrent pas de leurs tombeaux pour les démentir! pauvres gens!--ce n'est pas de schrevelius, de scapula et d'henri estienne que je parle. j'avais alors quelques amis illustres dans les lettres, qui répugnaient à m'abandonner sous le poids d'une accusation aussi capitale. ils auraient bien fait quelques concessions, mais romantique était un peu fort. ils avaient tenu bon longtemps. quand on leur parla de smarra, ils lâchèrent pied. la thessalie sonnait plus rudement à leurs oreilles que le scotland."larisse et le pénée, où diable a-t-il pris cela?" disait ce bon lémontey (dieu l'ait en sa sainte garde!)--c'étaient de rudes classiques, je vous en réponds! ce qu'il y a de particulier et de risible dans ce jugement, c'est qu'on ne fit grâce tout au plus qu'à certaines parties du style, et c'était à ma honte la seule chose qui fût de moi dans le livre. des conceptions fantastiques de l'esprit le plus éminent de la décadence, de l'image homérique, du tour virgilien, de ces figures de construction si laborieusement, et quelquefois si artistement calquées, il n'en fut pas question. on leur accorda d'être écrites, et c'était tout. imaginez, je vous prie, une statue comme l'apollon ou l'antinous sur laquelle un méchant manoeuvre a jeté en passant, pour s'en débarrasser, quelque pan de haillon, et que l'académie des beaux-arts trouve mauvaise, mais assez proprement drapée!... mon travail sur smarra n'est donc qu'un travail verbal, l'oeuvre d'un écolier attentif; il vaut tout au plus un prix de composition au collège, mais il ne valait pas tant de mépris; j'adressai quelques jours après à mon malheureux ami auger un exemplaire de smarra avec les renvois aux classiques, et je pense qu'il peut s'être trouvé dans sa bibliothèque. le lendemain, m. ponthieu, mon libraire, me fit la grâce de m'annoncer qu'il avait vendu l'édition au poids. j'avais tellement redouté de me mesurer avec la haute puissance d'expression qui caractérise l'antiquité, que je m'étais caché sous le rôle obscur de traducteur. les pièces qui suivaient smarra, et que je n'ai pas cru devoir supprimer, favorisaient cette supposition, que mon séjour assez long dans des provinces esclavonnes rendait d'ailleurs vraisemblable. c'étaient d'autres études que j'avais faites, jeune encore, sur une langue primitive, ou au moins autochtone, qui a pourtant son iliade, la belle osmanide de gondola, mais je ne pensais pas que cette précauti ...
# 2    les sylphes, tout étourdis du bruit de la veillée, descendent autour de vous en bourdonnant. ils frappent du battement monotone de leurs ailes de phalène vos yeux appesantis, et vous voyez longtemps flotter dans l'obscurité profonde la poussière transparente et bigarrée qui s'en échappe, comme un petit nuage lumineux au milieu d'un ciel éteint. ils se pressent, ils s'embrassent, ils se confondent, impatients de renouer la conversation magique des nuits précédentes, et de se raconter des événements inouïs qui se présentent cependant à votre esprit sous l'aspect d'une réminiscence merveilleuse. peu à peu leur voix s'affaiblit, ou bien elle ne vous parvient que par un organe inconnu qui transforme leurs récits en tableaux vivants, et qui vous rend acteur involontaire des scènes qu'ils ont préparées; car l'imagination de l'homme endormi, dans la puissance de son âme indépendante et solitaire, participe en quelque chose à la perfection des esprits. elle s'élance avec eux, et, portée par miracle au milieu du coeur aérien des songes, elle vole de surprise en surprise jusqu'à l'instant où le chant d'un oiseau matinal avertit son escorte aventureuse du retour de la lumière. effrayés du cri précurseur, ils se rassemblent comme un essaim d'abeilles au premier grondement du tonnerre, quand les larges gouttes de pluie font pencher la couronne des fleurs que l'hirondelle caresse sans les toucher. ils tombent, rebondissent, remontent, se croisent comme des atomes entraînés par des puissances contraires, et disparaissent en désordre dans un rayon du soleil. _"o rebus meis_ _non infideles arbitrae,_ _nox, et diana, quae silentium regis,_ _arcana cum fiunt sacra;_ _nunc, nunc adeste"_ _"o fidèles témoins de mes oeuvres, nuit et toi, diane qui entoures de silence nos sacrés mystères, venez maintenant, venez."_ _"par quel ordre ces esprits irrités viennent-ils m'effrayer de leurs clameurs et de leurs figures de lutins? qui roule devant moi ces rayons de feu? qui me fait perdre mon chemin dans la forêt? des singes hideux dont les dents grincent et mordent, ou bien des hérissons qui traversent exprès les sentiers pour se trouver sous mes pas et me blesser de leurs piquants."_ je venais d'achever mes études à l'école des philosophes d'athènes, et, curieux des beautés de la grèce, je visitais pour la première fois la poétique thessalie. mes esclaves m'attendaient à larisse dans un palais disposé pour me recevoir. j'avais voulu parcourir seul, et dans les heures imposantes de la nuit, cette forêt fameuse par les prestiges des magiciennes, qui étend de longs rideaux d'arbres verts sur les rives du pénée. les ombres épaisses qui s'accumulaient sur le dais immense des bois laissaient à peine s'échapper à travers quelques rameaux plus rares, dans une clairière ouverte sans doute par la cognée du bûcheron, le rayon tremblant d'une étoile pâle et cernée de brouillards. mes paupières appesanties se rabaissaient malgré moi sur mes yeux fatigués de chercher la trace blanchâtre du sentier qui s'effaçait dans le taillis, et je ne résistais au sommeil qu'en suivant d'une attention pénible le bruit des pieds de mon cheval, qui tantôt faisait crier l'arène, et tantôt gémir l'herbe sèche en retombant symétriquement sur la route. s'il s'arrêtait quelquefois, réveillé par son repos, je le nommais d'une voix forte, et je pressais sa marche devenue trop lente au gré de ma lassitude et de mon impatience. étonné de je ne sais quel obstacle inconnu, il s'élançait par bonds, roulant dans ses narines des hennissements de feu, se cabrait de terreur et reculait plus effrayé par les éclairs que les cailloux brisés faisaient jaillir sous ses pas.... --phlégon! phlégon, lui dis-je en frappant de ma tête accablée son cou qui se dressait d'épouvante, ô mon cher phlégon! n'est-il pas temps d'arriver à larisse où attendent les plaisirs et surtout le sommeil si doux! un instant de courage encore, et tu dormiras sur une litière de fleurs choisies; car la paille dorée qu'on recueil ...
# Name: Cleaned_Text, dtype: object

# %%
# Load French tokenizer
punkt_param = PunktParameters()
tokenizer = PunktSentenceTokenizer(punkt_param)

# %%
# Apply word tokenization
texts['Tokens'] = texts['Cleaned_Text'].apply(lambda x: word_tokenize(x, language='french'))

# %%
# Display first 3 tokenized text for verification
print(texts['Tokens'][:3])
# Out:
# index
# 0                                                                     [n'est, souvent, déterminée, que, par, un, mot, ., en, ce, point, même, ,, cependant, ,, il, n, ', a, fait, que, se, conformer, au, caprice, piquant, de, la, nature, ,, qui, se, joue, à, nous, faire, parcourir, dans, la, durée, d'un, seul, rêve, ,, plusieurs, fois, interrompu, par, des, épisodes, étrangers, à, son, objet, ,, tous, les, développements, d'une, action, régulière, ,, complète, et, plus, ou, moins, vraisemblable, ., les, personnes, qui, ont, lu, apulée, s'apercevront, facilement, que, la, fable, du, premier, livre, de, l'_âne, d'or_, de, cet, ingénieux, conteur, a, beaucoup, de, rapports, avec, celle-ci, ,, et, qu'elles, se, ...]
# 1                                                                                                              [le, reste, ne, me, regarde, point, ., j'ai, dit, de, qui, était, la, fable, :, sauf, quelques, phrases, de, transition, ,, tout, appartient, à, homère, ,, à, théocrite, ,, à, virgile, ,, à, catulle, ,, à, stace, ,, à, lucien, ,, à, dante, ,, à, shakespeare, ,, à, milton, ., je, ne, lisais, pas, autre, chose, ., le, défaut, criant, de, smarra, était, donc, de, paraître, ce, qu'il, était, réellement, ,, une, étude, ,, un, centon, ,, un, pastiche, des, classiques, ,, le, plus, mauvais, volumen, de, l'école, d'alexandrie, échappé, à, l'incendie, de, la, bibliothèque, des, ptolémées, ., personne, ne, ...]
# 2    [les, sylphes, ,, tout, étourdis, du, bruit, de, la, veillée, ,, descendent, autour, de, vous, en, bourdonnant, ., ils, frappent, du, battement, monotone, de, leurs, ailes, de, phalène, vos, yeux, appesantis, ,, et, vous, voyez, longtemps, flotter, dans, l'obscurité, profonde, la, poussière, transparente, et, bigarrée, qui, s'en, échappe, ,, comme, un, petit, nuage, lumineux, au, milieu, d'un, ciel, éteint, ., ils, se, pressent, ,, ils, s'embrassent, ,, ils, se, confondent, ,, impatients, de, renouer, la, conversation, magique, des, nuits, précédentes, ,, et, de, se, raconter, des, événements, inouïs, qui, se, présentent, cependant, à, votre, esprit, sous, l'aspect, d'une, réminiscence, merveilleuse, ...]
# Name: Tokens, dtype: object

# %%
# Drop authors and excerpts with < 25 excerpts
author_counts = texts['Author'].value_counts()
valid_authors = author_counts[author_counts > 25].index
texts = texts[texts['Author'].isin(valid_authors)]

# Filter final_authors
final_authors = final_authors[final_authors['Name'].isin(valid_authors)]

# Update books.csv
books = pd.read_csv('../Data/books.csv')
books = books[books['Author'].isin(valid_authors)]
books.to_csv('../Data/books.csv', index=False)

# Save updated data
texts.to_parquet('../Data/excerpts_df.parquet')
final_authors.to_csv('../Data/final_authors.csv', index=False)

# %%
final_authors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        28 non-null     object
#  1   birth_date  28 non-null     object
#  2   death_date  28 non-null     object
#  3   n_books     28 non-null     int64
#  4   Mouvement   28 non-null     object
#  5   Genres      28 non-null     object
#  6   n_excerpts  28 non-null     int64
# dtypes: int64(2), object(5)
# memory usage: 1.7+ KB

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Author     299 non-null    object
#  1   Title      299 non-null    object
#  2   Language   299 non-null    object
#  3   EBook-No   299 non-null    int64
#  4   URL        299 non-null    object
#  5   Roman      299 non-null    bool
#  6   Genres     299 non-null    object
#  7   Mouvement  299 non-null    object
#  8   Date       298 non-null    float64
# dtypes: bool(1), float64(1), int64(1), object(6)
# memory usage: 19.1+ KB

# %%
texts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14625 entries, 0 to 14657
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Author        14625 non-null  object
#  1   Title         14625 non-null  object
#  2   URL           14625 non-null  object
#  3   Excerpt_ID    14625 non-null  object
#  4   Excerpt_Text  14625 non-null  object
#  5   Cleaned_Text  14625 non-null  object
#  6   Tokens        14625 non-null  object
# dtypes: object(7)
# memory usage: 914.1+ KB

# %% [markdown]
# ## Data Aug

# %%
# Load OpenAI key

load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
# Delta Score Calculation

def compute_author_profiles(texts_df):
    """Creates stylometric profiles per author"""
    X = vectorizer.fit_transform(texts_df["Cleaned_Text"])
    features = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
    features["Author"] = texts_df["Author"].values

    # Compute mean frequencies per author
    author_profiles = features.groupby("Author").mean()

    # Z-score normalization (feature-wise)
    scaler = StandardScaler()
    scaled_profiles = pd.DataFrame(
        scaler.fit_transform(author_profiles),
        index=author_profiles.index,
        columns=author_profiles.columns
    )
    return scaled_profiles, scaler, vectorizer

def delta_score(text, scaled_author_profiles, scaler, vectorizer):
    """Compute Delta between one excerpt and all author profiles"""
    vec = vectorizer.transform([text])
    vec_df = pd.DataFrame(vec.toarray(), columns=vectorizer.get_feature_names_out())

    # Align columns
    for col in scaled_author_profiles.columns:
        if col not in vec_df.columns:
            vec_df[col] = 0
    vec_df = vec_df[scaled_author_profiles.columns]

    # Normalize using same scaler as author profiles
    vec_scaled = pd.DataFrame(
        scaler.transform(vec_df),
        columns=vec_df.columns
    ).iloc[0]

    # Compute Manhattan (L1) distance: Burrows’ Delta
    deltas = {}
    for author in scaled_author_profiles.index:
        profile = scaled_author_profiles.loc[author]
        deltas[author] = cityblock(vec_scaled, profile)

    return deltas


def get_delta_distribution_for_author(author, texts_df, profiles, scaler, vectorizer):
    subset = texts_df[texts_df["Author"] == author]["Cleaned_Text"]
    deltas = [delta_score(text, profiles, scaler, vectorizer)[author] for text in subset]
    return deltas

# %%
def build_prompt(target_author, example_1, example_2, input_excerpt, author_metadata):
    bio = (
        f"{target_author} est un écrivain français du {author_metadata['birth_date'][:4]}–{author_metadata['death_date'][:4]} siècle. "
        f"Appartenant au mouvement {author_metadata['Mouvement']}, il a principalement écrit dans les genres suivants : "
        f"{author_metadata['Genres']}."
    )

    return f"""
Tu es un modèle de génération de texte littéraire spécialisé dans l'augmentation de données pour la classification d'auteurs.

Ton rôle :
- Générer des extraits de fiction de 1500 mots (+/- 10%) en français.
- Respecter scrupuleusement le style de l’auteur : vocabulaire, syntaxe, ponctuation, ton, époque.
- Ne pas inclure de dialogues, titres ou en-têtes : que du texte narratif ou descriptif.
- Générer un passage qui suit naturellement celui donné, comme s’il s’agissait de la suite immédiate dans le livre.

Informations :
{bio}

Exemple de suite entre deux extraits d’un même livre de cet auteur:
--- Extrait A ---
{example_1}
--- Extrait B (suite de A) ---
{example_2}

Tâche :
Voici un extrait tiré de l’œuvre suivante : "{input_excerpt['Title']}". Génére la suite immédiate de cet extrait dans le même style, sans introduire de coupure ou de résumé.

--- Extrait donné ---
{input_excerpt['Excerpt_Text']}
--- Ta réponse (suite de l'extrait) ---
"""

# %%
def generate_and_validate(author_row, texts_df, n_needed, author_profiles, vectorizer, scaler, client):

    author_name = author_row["Name"]
    subset = texts_df[texts_df["Author"] == author_name].copy()

    # Extract book ID and position
    subset[["Book_ID", "Book_Pos"]] = subset["Excerpt_ID"].str.extract(r"(\d+)_(\d+)")
    subset["Book_Pos"] = subset["Book_Pos"].astype(int)

    # For each book, keep middle 50% of excerpts
    middle_excerpts = []
    for book_id, group in subset.groupby("Book_ID"):
        group_sorted = group.sort_values("Book_Pos")
        n = len(group_sorted)
        if n >= 4:
            middle = group_sorted.iloc[n // 4: 3 * n // 4]
            middle_excerpts.append(middle)
        else:
            # If too few excerpts, keep them all (fallback)
            middle_excerpts.append(group_sorted)

    middle_subset = pd.concat(middle_excerpts).reset_index(drop=True)


    new_excerpts = []
    attempts = 0
    max_attempts = 5 * n_needed 

    while len(new_excerpts) < n_needed and attempts < max_attempts:
        attempts += 1

        # Random consecutive excerpts for example
        examples = middle_subset.sample(2).sort_values("Excerpt_ID")
        example_1, example_2 = examples.iloc[0]["Excerpt_Text"], examples.iloc[1]["Excerpt_Text"]

        # Input excerpt also from middle
        input_excerpt = middle_subset.sample(1).iloc[0]

        prompt = build_prompt(
            target_author=author_name,
            example_1=example_1,
            example_2=example_2,
            input_excerpt=input_excerpt,
            author_metadata=author_row
        )

        try:
            print(f"Generating excerpt for {author_name}... (Attempt {attempts})")
            response = client.chat.completions.create(
                model="gpt-4.1-2025-04-14",
                messages=[{"role": "user", "content": prompt}],
                temperature=0.5,
                max_tokens=2048
            )
            generated = response.choices[0].message.content
            print(f"Generated excerpt for {author_name}: {generated[:100]}...")

            cleaned_gen = clean_text(generated)
            tokenized_gen = word_tokenize(cleaned_gen, language='french')
            print(len(tokenized_gen), "tokens in generated excerpt")
            length_ok = 1350 <= len(tokenized_gen) <= 1650

            delta_scores = delta_score(cleaned_gen, author_profiles, scaler, vectorizer)
            print(f"Delta scores for {author_name}: {delta_scores}")
            sorted_authors = sorted(delta_scores.items(), key=lambda x: x[1])
            closest_author, closest_score = sorted_authors[0]
            target_score = delta_scores[author_name]
            print(f"Closest author: {closest_author} ({closest_score:.2f}), Target author ({author_name}): {target_score:.2f}")

            # Allow small tolerance if author is nearly the closest
            tolerance = attempts / 100  # Make the tolerance increase with attempts
            delta_gap = abs(closest_score - target_score)
            is_closest_or_near = (
                closest_author == author_name or
                (target_score - closest_score) / closest_score <= tolerance
            )

            # Delta range check
            real_deltas = get_delta_distribution_for_author(
                author_name, texts_df, author_profiles, scaler, vectorizer
            )
            threshold = np.percentile(real_deltas, 90)
            within_range = target_score <= threshold

            print(f"Delta to {author_name}: {target_score:.2f} | 90th percentile: {threshold:.2f}")
            good_style = is_closest_or_near and within_range
            print(f"Excerpt length OK: {length_ok}, Good style: {good_style}")

            if length_ok and good_style:
                new_excerpts.append({
                    "Author": author_name,
                    "Title": input_excerpt["Title"],
                    "URL": input_excerpt["URL"],
                    "Excerpt_ID": f"{input_excerpt['Excerpt_ID']}_gen{len(new_excerpts)}",
                    "Excerpt_Text": generated,
                    "Cleaned_Text": cleaned_gen,
                    "Tokenized_Text": tokenized_gen,
                    "of_which_generated": input_excerpt["Excerpt_ID"]
                })
                print(f"✅ Accepted excerpt for {author_name}: {len(new_excerpts)} / {n_needed}")

        except Exception as e:
            print(f"Error (attempt {attempts}):", e)
            continue

    if len(new_excerpts) < n_needed:
        warnings.warn(
            f"⚠️ Could not generate all excerpts for {author_name}. Only {len(new_excerpts)} out of {n_needed} were accepted. Review needed."
        )

    return pd.DataFrame(new_excerpts)

# %%
# Precompute author profiles
author_profiles, scaler, vectorizer = compute_author_profiles(texts)

# Get underrepresented authors
need_aug = final_authors[final_authors["n_excerpts"] < 50]

print(f"Authors needing augmentation: {len(need_aug)}")
# Out:
# Authors needing augmentation: 4

# %%
augmented_all = []

client = client = openai.OpenAI()

for _, author_row in tqdm(need_aug.iterrows(), total=need_aug.shape[0]):
    n_needed = 50 - author_row["n_excerpts"]
    df_aug = generate_and_validate(author_row, texts, n_needed, author_profiles, vectorizer, scaler, client)
    augmented_all.append(df_aug)

augmented_df = pd.concat(augmented_all, ignore_index=True)

# Add new excerpts
texts = pd.concat([texts, augmented_df], ignore_index=True)

# Update author excerpt count
updated_counts = texts["Author"].value_counts().reset_index()
updated_counts.columns = ["Name", "n_excerpts"]
final_authors.update(updated_counts)

# Fill missing "of_which_generated" for real texts
texts["of_which_generated"] = texts.get("of_which_generated", np.nan)

# Save final versions
texts.to_parquet('../Data/excerpts_df.parquet', index=False)
final_authors.to_csv('../Data/final_authors.csv', index=False)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Generating excerpt for Charles Nodier... (Attempt 1)
# Generated excerpt for Charles Nodier: Dès lors, la maison de madame Alberti prit, sans qu’on s’en aperçût, une physionomie nouvelle. Il se...
# 1518 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(684.917461700297), 'Alexandre Dumas': np.float64(669.7759743701403), 'Alfred de Vigny': np.float64(699.8145589846887), 'Alphonse Daudet': np.float64(650.4940214335786), 'Anatole France': np.float64(611.0257418704662), 'André Gide': np.float64(669.8493259053164), 'Charles Nodier': np.float64(551.8406946660012), 'François Mauriac': np.float64(599.8796768482035), 'George Sand': np.float64(696.2068825461565), 'Georges Bernanos': np.float64(703.1687084132642), 'Gustave Flaubert': np.float64(613.3346308854663), 'Guy de Maupassant': np.float64(638.3237627725039), 'Henri Barbusse': np.float64(710.9329421727745), 'Honoré de Balzac': np.float64(704.3729619325727), 'Jules Renard': np.float64(703.4556478032977), 'Jules Vallès': np.float64(758.5845701886178), 'Jules Verne': np.float64(638.6399852619645), 'Marcel Proust': np.float64(764.7988580230759), 'Octave Mirbeau': np.float64(679.1299181268921), 'Paul Bourget': np.float64(697.3832317085895), 'Paul Féval': np.float64(710.7114671157015), 'Ponson du Terrail': np.float64(653.4685710720414), 'Prosper Mérimée': np.float64(675.4372456626892), 'Roger Martin du Gard': np.float64(719.9001637259005), 'Romain Rolland': np.float64(648.4862504931338), 'Stendhal': np.float64(689.6337278484211), 'Victor Hugo': np.float64(642.839349181469), 'Émile Zola': np.float64(648.2958696744413)}
# Closest author: Charles Nodier (551.84), Target author (Charles Nodier): 551.84
# Delta to Charles Nodier: 551.84 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: True
# ✅ Accepted excerpt for Charles Nodier: 1 / 12
# Generating excerpt for Charles Nodier... (Attempt 2)
# Generated excerpt for Charles Nodier: Lothario se pencha légèrement vers Antonia, et, dans ce mouvement, il y eut quelque chose d’une soll...
# 1515 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(713.0675311599952), 'Alexandre Dumas': np.float64(691.2300799832262), 'Alfred de Vigny': np.float64(691.5537856676341), 'Alphonse Daudet': np.float64(674.7129730672344), 'Anatole France': np.float64(630.7313974301699), 'André Gide': np.float64(681.6093797309852), 'Charles Nodier': np.float64(549.5050322969416), 'François Mauriac': np.float64(619.6374066802939), 'George Sand': np.float64(671.2185594190696), 'Georges Bernanos': np.float64(664.8637781375942), 'Gustave Flaubert': np.float64(626.6477353576529), 'Guy de Maupassant': np.float64(659.0497609440423), 'Henri Barbusse': np.float64(691.2901452084506), 'Honoré de Balzac': np.float64(692.2771758860006), 'Jules Renard': np.float64(686.6711723072071), 'Jules Vallès': np.float64(760.164316705474), 'Jules Verne': np.float64(653.1100722114383), 'Marcel Proust': np.float64(752.5300927663011), 'Octave Mirbeau': np.float64(674.0957701335212), 'Paul Bourget': np.float64(661.3996044264015), 'Paul Féval': np.float64(690.1994697768821), 'Ponson du Terrail': np.float64(678.078741012417), 'Prosper Mérimée': np.float64(686.6905764937039), 'Roger Martin du Gard': np.float64(673.5932860386903), 'Romain Rolland': np.float64(630.5580216053406), 'Stendhal': np.float64(700.619112962424), 'Victor Hugo': np.float64(652.6600339705005), 'Émile Zola': np.float64(672.5329752601288)}
# Closest author: Charles Nodier (549.51), Target author (Charles Nodier): 549.51
# Delta to Charles Nodier: 549.51 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: True
# ✅ Accepted excerpt for Charles Nodier: 2 / 12
# Generating excerpt for Charles Nodier... (Attempt 3)
# Generated excerpt for Charles Nodier: Mais déjà l’air s’emplit d’une langueur subtile, d’une vapeur tiède et lumineuse, où s’évanouissent ...
# 1411 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(677.3706065824938), 'Alexandre Dumas': np.float64(695.7186207813595), 'Alfred de Vigny': np.float64(701.0410022041782), 'Alphonse Daudet': np.float64(637.8174121644086), 'Anatole France': np.float64(638.6837829940514), 'André Gide': np.float64(676.2399434492035), 'Charles Nodier': np.float64(586.6253037755596), 'François Mauriac': np.float64(602.343212881369), 'George Sand': np.float64(726.7427029483576), 'Georges Bernanos': np.float64(657.2864436251593), 'Gustave Flaubert': np.float64(613.9917819404724), 'Guy de Maupassant': np.float64(628.2558607116921), 'Henri Barbusse': np.float64(620.6149455695829), 'Honoré de Balzac': np.float64(731.5540509178651), 'Jules Renard': np.float64(633.2185910037113), 'Jules Vallès': np.float64(729.0511175799523), 'Jules Verne': np.float64(661.2182527779927), 'Marcel Proust': np.float64(822.9881501583749), 'Octave Mirbeau': np.float64(636.4164371915222), 'Paul Bourget': np.float64(733.1531246709977), 'Paul Féval': np.float64(712.6790923527329), 'Ponson du Terrail': np.float64(670.7900508828416), 'Prosper Mérimée': np.float64(707.3153527493331), 'Roger Martin du Gard': np.float64(669.1479077715742), 'Romain Rolland': np.float64(679.0894561610097), 'Stendhal': np.float64(752.3209045641132), 'Victor Hugo': np.float64(635.0335918638312), 'Émile Zola': np.float64(664.4151760295941)}
# Closest author: Charles Nodier (586.63), Target author (Charles Nodier): 586.63
# Delta to Charles Nodier: 586.63 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: True
# ✅ Accepted excerpt for Charles Nodier: 3 / 12
# Generating excerpt for Charles Nodier... (Attempt 4)
# Generated excerpt for Charles Nodier: L’air, saturé d’exhalaisons méphitiques, oppressait ma poitrine d’un poids insupportable ; il me sem...
# 1460 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(715.8012395361211), 'Alexandre Dumas': np.float64(723.8595736518066), 'Alfred de Vigny': np.float64(730.2350608000331), 'Alphonse Daudet': np.float64(690.4101859951866), 'Anatole France': np.float64(666.9892111256686), 'André Gide': np.float64(741.1404115152922), 'Charles Nodier': np.float64(617.5672587454033), 'François Mauriac': np.float64(649.0008411785559), 'George Sand': np.float64(757.3052475533473), 'Georges Bernanos': np.float64(724.3589532795357), 'Gustave Flaubert': np.float64(656.9911856406325), 'Guy de Maupassant': np.float64(677.8667436205931), 'Henri Barbusse': np.float64(673.0734294670406), 'Honoré de Balzac': np.float64(770.3111926826034), 'Jules Renard': np.float64(696.296559906312), 'Jules Vallès': np.float64(777.5767054101569), 'Jules Verne': np.float64(695.0714628252049), 'Marcel Proust': np.float64(840.0945132748782), 'Octave Mirbeau': np.float64(681.2778321684128), 'Paul Bourget': np.float64(766.0525453246084), 'Paul Féval': np.float64(752.8041731651438), 'Ponson du Terrail': np.float64(720.1184113627155), 'Prosper Mérimée': np.float64(736.6644952581291), 'Roger Martin du Gard': np.float64(739.6670810335395), 'Romain Rolland': np.float64(714.3195780570278), 'Stendhal': np.float64(788.0477250103459), 'Victor Hugo': np.float64(686.8908063789515), 'Émile Zola': np.float64(731.169802856291)}
# Closest author: Charles Nodier (617.57), Target author (Charles Nodier): 617.57
# Delta to Charles Nodier: 617.57 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: False
# Generating excerpt for Charles Nodier... (Attempt 5)
# Generated excerpt for Charles Nodier: L’assemblée, suspendue à ce prélude, écoutait dans un silence religieux, où l’on n’entendait plus qu...
# 1470 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(712.6632561671596), 'Alexandre Dumas': np.float64(721.5246542355301), 'Alfred de Vigny': np.float64(728.4971067359288), 'Alphonse Daudet': np.float64(686.4449666124036), 'Anatole France': np.float64(661.6100709433957), 'André Gide': np.float64(705.203866203185), 'Charles Nodier': np.float64(608.1467944870876), 'François Mauriac': np.float64(629.583477684821), 'George Sand': np.float64(730.5916235330371), 'Georges Bernanos': np.float64(715.8619663268736), 'Gustave Flaubert': np.float64(666.5206240823852), 'Guy de Maupassant': np.float64(681.0701516545728), 'Henri Barbusse': np.float64(727.8459459679274), 'Honoré de Balzac': np.float64(729.9758703618897), 'Jules Renard': np.float64(710.0992965047001), 'Jules Vallès': np.float64(764.6578371287646), 'Jules Verne': np.float64(678.7117023232751), 'Marcel Proust': np.float64(802.7495912539162), 'Octave Mirbeau': np.float64(701.9407227769982), 'Paul Bourget': np.float64(716.9102143630123), 'Paul Féval': np.float64(747.3218332910187), 'Ponson du Terrail': np.float64(690.4164687040943), 'Prosper Mérimée': np.float64(712.291913146842), 'Roger Martin du Gard': np.float64(745.5303036619291), 'Romain Rolland': np.float64(679.0814846027807), 'Stendhal': np.float64(738.8620112727101), 'Victor Hugo': np.float64(676.4753204572526), 'Émile Zola': np.float64(705.3918342770655)}
# Closest author: Charles Nodier (608.15), Target author (Charles Nodier): 608.15
# Delta to Charles Nodier: 608.15 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: False
# Generating excerpt for Charles Nodier... (Attempt 6)
# Generated excerpt for Charles Nodier: Polémon détourna lentement la tête, comme accablé sous le poids d’une pensée dont la source était au...
# 1293 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(729.5937639544728), 'Alexandre Dumas': np.float64(752.1483760700887), 'Alfred de Vigny': np.float64(737.8365597551675), 'Alphonse Daudet': np.float64(693.0829214804828), 'Anatole France': np.float64(685.6468888649101), 'André Gide': np.float64(724.2968109237329), 'Charles Nodier': np.float64(621.3046047291195), 'François Mauriac': np.float64(643.1323078509686), 'George Sand': np.float64(758.0722256118959), 'Georges Bernanos': np.float64(711.1805485240995), 'Gustave Flaubert': np.float64(670.8775704957377), 'Guy de Maupassant': np.float64(694.5872896557296), 'Henri Barbusse': np.float64(666.7753150759312), 'Honoré de Balzac': np.float64(781.4591768486604), 'Jules Renard': np.float64(686.1512526416144), 'Jules Vallès': np.float64(782.0868443646154), 'Jules Verne': np.float64(700.2163250659457), 'Marcel Proust': np.float64(869.1619061610315), 'Octave Mirbeau': np.float64(690.5277061255813), 'Paul Bourget': np.float64(802.1765584432499), 'Paul Féval': np.float64(770.0571793917534), 'Ponson du Terrail': np.float64(731.4577686440872), 'Prosper Mérimée': np.float64(752.5345540868639), 'Roger Martin du Gard': np.float64(745.4717881111162), 'Romain Rolland': np.float64(719.3176260880898), 'Stendhal': np.float64(810.2089910355793), 'Victor Hugo': np.float64(722.0707923910567), 'Émile Zola': np.float64(735.1673964070424)}
# Closest author: Charles Nodier (621.30), Target author (Charles Nodier): 621.30
# Delta to Charles Nodier: 621.30 | 90th percentile: 602.03
# Excerpt length OK: False, Good style: False
# Generating excerpt for Charles Nodier... (Attempt 7)
# Generated excerpt for Charles Nodier: Alors, je demeurai seul, accablé d’une langueur étrange, sentant encore sur ma poitrine la trace gla...
# 1368 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(713.5814974477072), 'Alexandre Dumas': np.float64(700.436146337659), 'Alfred de Vigny': np.float64(702.5504289223384), 'Alphonse Daudet': np.float64(666.2660530476453), 'Anatole France': np.float64(632.5088321401006), 'André Gide': np.float64(686.3407718410863), 'Charles Nodier': np.float64(583.3493010275329), 'François Mauriac': np.float64(623.1012735443726), 'George Sand': np.float64(714.6653727787689), 'Georges Bernanos': np.float64(692.5690028719341), 'Gustave Flaubert': np.float64(639.4022913609332), 'Guy de Maupassant': np.float64(671.9021343866591), 'Henri Barbusse': np.float64(669.1110220260214), 'Honoré de Balzac': np.float64(748.1071607357774), 'Jules Renard': np.float64(670.4302068917559), 'Jules Vallès': np.float64(743.9420056773101), 'Jules Verne': np.float64(681.0392161257187), 'Marcel Proust': np.float64(801.0630785269437), 'Octave Mirbeau': np.float64(649.3988388052628), 'Paul Bourget': np.float64(718.7758196946925), 'Paul Féval': np.float64(727.6615176938319), 'Ponson du Terrail': np.float64(687.4770833178537), 'Prosper Mérimée': np.float64(693.1196727251405), 'Roger Martin du Gard': np.float64(712.9979398158), 'Romain Rolland': np.float64(688.9273021333036), 'Stendhal': np.float64(763.9578444063516), 'Victor Hugo': np.float64(673.2446215250927), 'Émile Zola': np.float64(689.8406251884594)}
# Closest author: Charles Nodier (583.35), Target author (Charles Nodier): 583.35
# Delta to Charles Nodier: 583.35 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: True
# ✅ Accepted excerpt for Charles Nodier: 4 / 12
# Generating excerpt for Charles Nodier... (Attempt 8)
# Generated excerpt for Charles Nodier: Un silence solennel, que le timbre grave de la voix de Matteo semblait avoir imposé à la petite asse...
# 1485 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(649.2757662696215), 'Alexandre Dumas': np.float64(653.0180499253854), 'Alfred de Vigny': np.float64(682.3902467441702), 'Alphonse Daudet': np.float64(635.5032009228227), 'Anatole France': np.float64(608.7256243759655), 'André Gide': np.float64(636.9185442798002), 'Charles Nodier': np.float64(576.8089856747538), 'François Mauriac': np.float64(576.0694941418562), 'George Sand': np.float64(681.835848515348), 'Georges Bernanos': np.float64(649.4326545949747), 'Gustave Flaubert': np.float64(617.8549050103306), 'Guy de Maupassant': np.float64(630.1756246990853), 'Henri Barbusse': np.float64(681.0048457001324), 'Honoré de Balzac': np.float64(706.4202078561007), 'Jules Renard': np.float64(679.0158556505169), 'Jules Vallès': np.float64(760.1924668769742), 'Jules Verne': np.float64(625.0180679242192), 'Marcel Proust': np.float64(756.5860514643377), 'Octave Mirbeau': np.float64(666.4066402663225), 'Paul Bourget': np.float64(680.0640295043423), 'Paul Féval': np.float64(702.4278270251561), 'Ponson du Terrail': np.float64(647.1487383116914), 'Prosper Mérimée': np.float64(665.7100021365793), 'Roger Martin du Gard': np.float64(676.4603320573636), 'Romain Rolland': np.float64(617.7070028054052), 'Stendhal': np.float64(694.0304108501188), 'Victor Hugo': np.float64(638.5670344403441), 'Émile Zola': np.float64(632.3573397710622)}
# Closest author: François Mauriac (576.07), Target author (Charles Nodier): 576.81
# Delta to Charles Nodier: 576.81 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: True
# ✅ Accepted excerpt for Charles Nodier: 5 / 12
# Generating excerpt for Charles Nodier... (Attempt 9)
# Generated excerpt for Charles Nodier: Il semblait que la maison tout entière, depuis quelques jours, fût enveloppée d’une atmosphère de tr...
# 1542 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(682.3728016249806), 'Alexandre Dumas': np.float64(720.2631279105917), 'Alfred de Vigny': np.float64(740.4036870855746), 'Alphonse Daudet': np.float64(687.724261439827), 'Anatole France': np.float64(708.3444122870008), 'André Gide': np.float64(685.3537872041404), 'Charles Nodier': np.float64(615.1413667057129), 'François Mauriac': np.float64(602.0150346766673), 'George Sand': np.float64(738.9424507781121), 'Georges Bernanos': np.float64(689.3041738486213), 'Gustave Flaubert': np.float64(654.8306075268933), 'Guy de Maupassant': np.float64(663.9038822874518), 'Henri Barbusse': np.float64(727.7336256878585), 'Honoré de Balzac': np.float64(750.6709355569135), 'Jules Renard': np.float64(729.519224767395), 'Jules Vallès': np.float64(786.2519950501736), 'Jules Verne': np.float64(680.510183822123), 'Marcel Proust': np.float64(772.846887013166), 'Octave Mirbeau': np.float64(704.7381343833576), 'Paul Bourget': np.float64(718.5005806977867), 'Paul Féval': np.float64(759.9808223176456), 'Ponson du Terrail': np.float64(711.7628068652974), 'Prosper Mérimée': np.float64(723.0264437593618), 'Roger Martin du Gard': np.float64(737.2270208861673), 'Romain Rolland': np.float64(671.501610808115), 'Stendhal': np.float64(718.7008259131319), 'Victor Hugo': np.float64(694.1755873363188), 'Émile Zola': np.float64(689.2992084056168)}
# Closest author: François Mauriac (602.02), Target author (Charles Nodier): 615.14
# Delta to Charles Nodier: 615.14 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: False
# Generating excerpt for Charles Nodier... (Attempt 10)
# Generated excerpt for Charles Nodier: La nuit s’épaississait peu à peu sur la lagune, enveloppant de son voile humide les contours incerta...
# 1492 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(657.4274086932337), 'Alexandre Dumas': np.float64(659.4747819835923), 'Alfred de Vigny': np.float64(690.1562562626119), 'Alphonse Daudet': np.float64(622.3469204102121), 'Anatole France': np.float64(610.8119903658121), 'André Gide': np.float64(623.9411497034588), 'Charles Nodier': np.float64(580.6300435641836), 'François Mauriac': np.float64(582.1943946399358), 'George Sand': np.float64(698.3214028142714), 'Georges Bernanos': np.float64(677.8155067390976), 'Gustave Flaubert': np.float64(611.1873043097489), 'Guy de Maupassant': np.float64(625.8930624271635), 'Henri Barbusse': np.float64(662.5096161774192), 'Honoré de Balzac': np.float64(702.82797008656), 'Jules Renard': np.float64(662.9420541906047), 'Jules Vallès': np.float64(733.6264111831667), 'Jules Verne': np.float64(639.1300173506957), 'Marcel Proust': np.float64(765.7887380323489), 'Octave Mirbeau': np.float64(661.0084889071907), 'Paul Bourget': np.float64(693.5455021436459), 'Paul Féval': np.float64(703.5447574649564), 'Ponson du Terrail': np.float64(640.5522799305269), 'Prosper Mérimée': np.float64(661.3845614747877), 'Roger Martin du Gard': np.float64(689.5065182102419), 'Romain Rolland': np.float64(638.2511908739114), 'Stendhal': np.float64(690.4073740415422), 'Victor Hugo': np.float64(626.5420364280665), 'Émile Zola': np.float64(634.8751557279768)}
# Closest author: Charles Nodier (580.63), Target author (Charles Nodier): 580.63
# Delta to Charles Nodier: 580.63 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: True
# ✅ Accepted excerpt for Charles Nodier: 6 / 12
# Generating excerpt for Charles Nodier... (Attempt 11)
# Generated excerpt for Charles Nodier: Mais vois, Polémon, comme la nuit s’avance paisible et profonde, enveloppant de son manteau d’ombre ...
# 1396 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(714.9024184226432), 'Alexandre Dumas': np.float64(712.1410856214673), 'Alfred de Vigny': np.float64(702.4281024031696), 'Alphonse Daudet': np.float64(652.4479727662695), 'Anatole France': np.float64(629.1223903319374), 'André Gide': np.float64(698.5904784423291), 'Charles Nodier': np.float64(586.5447143530571), 'François Mauriac': np.float64(616.3785235248827), 'George Sand': np.float64(719.2160730984376), 'Georges Bernanos': np.float64(711.6249137960441), 'Gustave Flaubert': np.float64(628.3456003141368), 'Guy de Maupassant': np.float64(666.3205679898557), 'Henri Barbusse': np.float64(639.1791460840442), 'Honoré de Balzac': np.float64(731.8023450747969), 'Jules Renard': np.float64(644.7897526535257), 'Jules Vallès': np.float64(739.4469513333787), 'Jules Verne': np.float64(667.3361076717187), 'Marcel Proust': np.float64(827.8433460152855), 'Octave Mirbeau': np.float64(656.761864413152), 'Paul Bourget': np.float64(745.4011989698322), 'Paul Féval': np.float64(737.2730439751662), 'Ponson du Terrail': np.float64(690.1977740501468), 'Prosper Mérimée': np.float64(713.1957932029351), 'Roger Martin du Gard': np.float64(689.1782128656996), 'Romain Rolland': np.float64(688.4975910084747), 'Stendhal': np.float64(754.786889140403), 'Victor Hugo': np.float64(671.7071927669637), 'Émile Zola': np.float64(706.7027984503034)}
# Closest author: Charles Nodier (586.54), Target author (Charles Nodier): 586.54
# Delta to Charles Nodier: 586.54 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: True
# ✅ Accepted excerpt for Charles Nodier: 7 / 12
# Generating excerpt for Charles Nodier... (Attempt 12)
# Generated excerpt for Charles Nodier: Un frisson parcourut tout le corps d’Antonia, comme si la brise nocturne s’était faite subitement gl...
# 1511 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(732.4222579716277), 'Alexandre Dumas': np.float64(750.7540915372064), 'Alfred de Vigny': np.float64(746.6454183426879), 'Alphonse Daudet': np.float64(714.5131924546482), 'Anatole France': np.float64(700.0189354597567), 'André Gide': np.float64(708.9396532386406), 'Charles Nodier': np.float64(633.1414976055953), 'François Mauriac': np.float64(663.0752696933089), 'George Sand': np.float64(770.1290968471246), 'Georges Bernanos': np.float64(671.994574262651), 'Gustave Flaubert': np.float64(659.9119561644604), 'Guy de Maupassant': np.float64(686.8037795636396), 'Henri Barbusse': np.float64(723.5257087688501), 'Honoré de Balzac': np.float64(790.0700031489902), 'Jules Renard': np.float64(715.6225893039837), 'Jules Vallès': np.float64(809.8822693670318), 'Jules Verne': np.float64(710.0407424773739), 'Marcel Proust': np.float64(861.7604716522158), 'Octave Mirbeau': np.float64(714.628590157846), 'Paul Bourget': np.float64(765.3165454923258), 'Paul Féval': np.float64(769.7908590452624), 'Ponson du Terrail': np.float64(715.7039875487089), 'Prosper Mérimée': np.float64(722.9339340227983), 'Roger Martin du Gard': np.float64(750.8926322416768), 'Romain Rolland': np.float64(710.689070780571), 'Stendhal': np.float64(778.8514417489656), 'Victor Hugo': np.float64(696.6384983634964), 'Émile Zola': np.float64(730.5935845732748)}
# Closest author: Charles Nodier (633.14), Target author (Charles Nodier): 633.14
# Delta to Charles Nodier: 633.14 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: False
# Generating excerpt for Charles Nodier... (Attempt 13)
# Generated excerpt for Charles Nodier: À ces mots, un silence singulier s’étendit dans le salon, comme si la parole de madame Alberti, écha...
# 1474 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(666.3844389799139), 'Alexandre Dumas': np.float64(675.6036555704067), 'Alfred de Vigny': np.float64(711.2800661817064), 'Alphonse Daudet': np.float64(658.7296305722192), 'Anatole France': np.float64(631.3790626060472), 'André Gide': np.float64(693.1348276828621), 'Charles Nodier': np.float64(591.9677873112555), 'François Mauriac': np.float64(599.1774431932627), 'George Sand': np.float64(724.3892280454629), 'Georges Bernanos': np.float64(694.6933702692706), 'Gustave Flaubert': np.float64(616.966406965916), 'Guy de Maupassant': np.float64(644.9894489860865), 'Henri Barbusse': np.float64(688.9619510021771), 'Honoré de Balzac': np.float64(711.6537575220216), 'Jules Renard': np.float64(694.7551614807302), 'Jules Vallès': np.float64(775.5957206182889), 'Jules Verne': np.float64(658.7578817453377), 'Marcel Proust': np.float64(791.9891565495019), 'Octave Mirbeau': np.float64(665.5629277865373), 'Paul Bourget': np.float64(705.3988097366318), 'Paul Féval': np.float64(715.56845398858), 'Ponson du Terrail': np.float64(659.6597374090702), 'Prosper Mérimée': np.float64(691.3433695176208), 'Roger Martin du Gard': np.float64(729.2398479708761), 'Romain Rolland': np.float64(665.3060494659455), 'Stendhal': np.float64(725.1790710426874), 'Victor Hugo': np.float64(649.602045856568), 'Émile Zola': np.float64(665.2323609097182)}
# Closest author: Charles Nodier (591.97), Target author (Charles Nodier): 591.97
# Delta to Charles Nodier: 591.97 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: True
# ✅ Accepted excerpt for Charles Nodier: 8 / 12
# Generating excerpt for Charles Nodier... (Attempt 14)
# Generated excerpt for Charles Nodier: Cependant, ces larmes, que Lothario ne montrait à personne, que dans l’ombre d’une confidence ou le ...
# 1523 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(682.255028392276), 'Alexandre Dumas': np.float64(672.8284257644234), 'Alfred de Vigny': np.float64(690.8319189675367), 'Alphonse Daudet': np.float64(663.8111337981439), 'Anatole France': np.float64(634.0836949047996), 'André Gide': np.float64(658.2037668222201), 'Charles Nodier': np.float64(562.1479342072728), 'François Mauriac': np.float64(594.567132603467), 'George Sand': np.float64(677.6978912659351), 'Georges Bernanos': np.float64(652.3980451877939), 'Gustave Flaubert': np.float64(626.8691119107602), 'Guy de Maupassant': np.float64(631.9207829429536), 'Henri Barbusse': np.float64(701.4177710658471), 'Honoré de Balzac': np.float64(692.0424836931771), 'Jules Renard': np.float64(686.0422284837169), 'Jules Vallès': np.float64(743.6655263681926), 'Jules Verne': np.float64(643.8675925555419), 'Marcel Proust': np.float64(751.5330699846592), 'Octave Mirbeau': np.float64(648.9511265872936), 'Paul Bourget': np.float64(664.9224553389483), 'Paul Féval': np.float64(698.6673548189084), 'Ponson du Terrail': np.float64(656.6122293424428), 'Prosper Mérimée': np.float64(679.0606257398806), 'Roger Martin du Gard': np.float64(694.0401584189633), 'Romain Rolland': np.float64(630.9170311320659), 'Stendhal': np.float64(694.608758602961), 'Victor Hugo': np.float64(649.784022575144), 'Émile Zola': np.float64(649.1270411795107)}
# Closest author: Charles Nodier (562.15), Target author (Charles Nodier): 562.15
# Delta to Charles Nodier: 562.15 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: True
# ✅ Accepted excerpt for Charles Nodier: 9 / 12
# Generating excerpt for Charles Nodier... (Attempt 15)
# Generated excerpt for Charles Nodier: La nuit s’avançait silencieuse sur la lagune, et le grand salon, où la conversation de Matteo venait...
# 1503 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(673.8564375626369), 'Alexandre Dumas': np.float64(665.0634747581156), 'Alfred de Vigny': np.float64(676.2716884986241), 'Alphonse Daudet': np.float64(614.4847257947407), 'Anatole France': np.float64(610.8720129641262), 'André Gide': np.float64(644.8496683787666), 'Charles Nodier': np.float64(565.3036392745718), 'François Mauriac': np.float64(573.3006448347314), 'George Sand': np.float64(696.7290573230985), 'Georges Bernanos': np.float64(668.7571692942796), 'Gustave Flaubert': np.float64(590.8349770866635), 'Guy de Maupassant': np.float64(613.4186432009617), 'Henri Barbusse': np.float64(683.0815796954852), 'Honoré de Balzac': np.float64(686.5285114395678), 'Jules Renard': np.float64(644.254902284445), 'Jules Vallès': np.float64(741.1840034865984), 'Jules Verne': np.float64(645.184536982448), 'Marcel Proust': np.float64(762.4482161624069), 'Octave Mirbeau': np.float64(658.8551839809868), 'Paul Bourget': np.float64(702.2573930326985), 'Paul Féval': np.float64(684.0118038608252), 'Ponson du Terrail': np.float64(646.2599719153279), 'Prosper Mérimée': np.float64(658.6689761095167), 'Roger Martin du Gard': np.float64(703.9305912975922), 'Romain Rolland': np.float64(621.8989101699683), 'Stendhal': np.float64(697.7362812794686), 'Victor Hugo': np.float64(617.7027597403945), 'Émile Zola': np.float64(646.9921677394336)}
# Closest author: Charles Nodier (565.30), Target author (Charles Nodier): 565.30
# Delta to Charles Nodier: 565.30 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: True
# ✅ Accepted excerpt for Charles Nodier: 10 / 12
# Generating excerpt for Charles Nodier... (Attempt 16)
# Generated excerpt for Charles Nodier: Mais déjà, la nuit, cette grande magicienne, étendait plus loin ses voiles de gaze sur la salle où s...
# 1435 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(739.0890651113305), 'Alexandre Dumas': np.float64(749.1876603442186), 'Alfred de Vigny': np.float64(746.3140649710496), 'Alphonse Daudet': np.float64(686.9611784895824), 'Anatole France': np.float64(659.387321272081), 'André Gide': np.float64(728.9291024500824), 'Charles Nodier': np.float64(645.1753675855523), 'François Mauriac': np.float64(651.0687163731652), 'George Sand': np.float64(764.9854572007969), 'Georges Bernanos': np.float64(732.6044318587981), 'Gustave Flaubert': np.float64(650.1923224482766), 'Guy de Maupassant': np.float64(683.9569170366376), 'Henri Barbusse': np.float64(698.847803421101), 'Honoré de Balzac': np.float64(780.4338394262702), 'Jules Renard': np.float64(694.4414139477211), 'Jules Vallès': np.float64(781.6057278479743), 'Jules Verne': np.float64(686.9240529733389), 'Marcel Proust': np.float64(870.5897589692615), 'Octave Mirbeau': np.float64(718.2394806937991), 'Paul Bourget': np.float64(793.9620353771717), 'Paul Féval': np.float64(774.1372101183651), 'Ponson du Terrail': np.float64(705.0746016469925), 'Prosper Mérimée': np.float64(744.0666646693919), 'Roger Martin du Gard': np.float64(759.5174277535033), 'Romain Rolland': np.float64(731.8959669571279), 'Stendhal': np.float64(807.0037625865058), 'Victor Hugo': np.float64(691.3484271917632), 'Émile Zola': np.float64(711.2035365053252)}
# Closest author: Charles Nodier (645.18), Target author (Charles Nodier): 645.18
# Delta to Charles Nodier: 645.18 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: False
# Generating excerpt for Charles Nodier... (Attempt 17)
# Generated excerpt for Charles Nodier: La procession silencieuse des voitures s’étirait dans la pénombre, pareille à quelque antique cortèg...
# 1474 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(667.8127996181211), 'Alexandre Dumas': np.float64(698.2673588934686), 'Alfred de Vigny': np.float64(724.4372569466791), 'Alphonse Daudet': np.float64(646.6415476006434), 'Anatole France': np.float64(634.2054176002205), 'André Gide': np.float64(662.1109404668217), 'Charles Nodier': np.float64(606.9076813433747), 'François Mauriac': np.float64(610.3540078698874), 'George Sand': np.float64(741.4604368661354), 'Georges Bernanos': np.float64(707.1914403296892), 'Gustave Flaubert': np.float64(612.942692776277), 'Guy de Maupassant': np.float64(645.2897013714177), 'Henri Barbusse': np.float64(701.9354480884531), 'Honoré de Balzac': np.float64(730.7698103767659), 'Jules Renard': np.float64(706.7969287816175), 'Jules Vallès': np.float64(760.9019866103326), 'Jules Verne': np.float64(649.7529827476199), 'Marcel Proust': np.float64(804.1647824798401), 'Octave Mirbeau': np.float64(698.8359983410278), 'Paul Bourget': np.float64(725.8207194518883), 'Paul Féval': np.float64(721.0879617467428), 'Ponson du Terrail': np.float64(672.5389420789115), 'Prosper Mérimée': np.float64(704.5432363607808), 'Roger Martin du Gard': np.float64(736.5277690844172), 'Romain Rolland': np.float64(681.3663917152716), 'Stendhal': np.float64(745.2566870225919), 'Victor Hugo': np.float64(646.6893490822853), 'Émile Zola': np.float64(657.9247743410261)}
# Closest author: Charles Nodier (606.91), Target author (Charles Nodier): 606.91
# Delta to Charles Nodier: 606.91 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: False
# Generating excerpt for Charles Nodier... (Attempt 18)
# Generated excerpt for Charles Nodier: Mais le désespoir, ce sombre génie de la nuit, se glisse partout, même sous les voûtes dorées où l’o...
# 1509 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(694.4078309121358), 'Alexandre Dumas': np.float64(698.980006801526), 'Alfred de Vigny': np.float64(711.6713431855045), 'Alphonse Daudet': np.float64(668.1886684204615), 'Anatole France': np.float64(655.1007461173028), 'André Gide': np.float64(688.6460458316772), 'Charles Nodier': np.float64(589.7937270247411), 'François Mauriac': np.float64(625.6208623238435), 'George Sand': np.float64(734.8667104128585), 'Georges Bernanos': np.float64(704.1828223097309), 'Gustave Flaubert': np.float64(624.6411015346675), 'Guy de Maupassant': np.float64(659.204580557469), 'Henri Barbusse': np.float64(692.395350201193), 'Honoré de Balzac': np.float64(748.3846929178194), 'Jules Renard': np.float64(709.3010026110404), 'Jules Vallès': np.float64(775.6104939985571), 'Jules Verne': np.float64(681.0030004092202), 'Marcel Proust': np.float64(812.9867155600218), 'Octave Mirbeau': np.float64(687.2732035302404), 'Paul Bourget': np.float64(734.5412331627044), 'Paul Féval': np.float64(731.4989087035872), 'Ponson du Terrail': np.float64(665.5782300648095), 'Prosper Mérimée': np.float64(713.2277944089346), 'Roger Martin du Gard': np.float64(724.6031762044042), 'Romain Rolland': np.float64(679.9412350686544), 'Stendhal': np.float64(758.6101409135985), 'Victor Hugo': np.float64(659.9833591812564), 'Émile Zola': np.float64(667.6780022058442)}
# Closest author: Charles Nodier (589.79), Target author (Charles Nodier): 589.79
# Delta to Charles Nodier: 589.79 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: True
# ✅ Accepted excerpt for Charles Nodier: 11 / 12
# Generating excerpt for Charles Nodier... (Attempt 19)
#  25%|██▌       | 1/4 [14:35<43:46, 875.41s/it]
# Generated excerpt for Charles Nodier: C’est ainsi que les jours s’écoulèrent dans un demi-repos, une attente inquiète, où le présent s’emp...
# 1494 tokens in generated excerpt
# Delta scores for Charles Nodier: {'Alain-Fournier': np.float64(711.9001017550061), 'Alexandre Dumas': np.float64(710.6140497980475), 'Alfred de Vigny': np.float64(735.7433295293812), 'Alphonse Daudet': np.float64(670.209882292147), 'Anatole France': np.float64(637.9970458313135), 'André Gide': np.float64(705.6221235236378), 'Charles Nodier': np.float64(600.2539611649038), 'François Mauriac': np.float64(602.7206821139447), 'George Sand': np.float64(740.0998088091349), 'Georges Bernanos': np.float64(717.0560902355104), 'Gustave Flaubert': np.float64(635.5680392367825), 'Guy de Maupassant': np.float64(676.9460511182372), 'Henri Barbusse': np.float64(707.5574167652003), 'Honoré de Balzac': np.float64(735.9861038872733), 'Jules Renard': np.float64(730.8092447058127), 'Jules Vallès': np.float64(776.9470054261221), 'Jules Verne': np.float64(667.9449571881948), 'Marcel Proust': np.float64(797.671427820835), 'Octave Mirbeau': np.float64(690.25807941971), 'Paul Bourget': np.float64(729.8225133529188), 'Paul Féval': np.float64(748.6529190782364), 'Ponson du Terrail': np.float64(698.3627172943404), 'Prosper Mérimée': np.float64(718.5154339469985), 'Roger Martin du Gard': np.float64(751.3427700496076), 'Romain Rolland': np.float64(668.3018735577004), 'Stendhal': np.float64(731.5907236537449), 'Victor Hugo': np.float64(667.6083623681342), 'Émile Zola': np.float64(685.8928932584013)}
# Closest author: Charles Nodier (600.25), Target author (Charles Nodier): 600.25
# Delta to Charles Nodier: 600.25 | 90th percentile: 602.03
# Excerpt length OK: True, Good style: True
# ✅ Accepted excerpt for Charles Nodier: 12 / 12
# Generating excerpt for Prosper Mérimée... (Attempt 1)
# Generated excerpt for Prosper Mérimée: Le repas se prolongea dans une animation croissante, comme si l’allégresse du vin, du soleil et des ...
# 1482 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(636.0313009271991), 'Alexandre Dumas': np.float64(669.0166160635372), 'Alfred de Vigny': np.float64(685.70359878059), 'Alphonse Daudet': np.float64(616.739157872463), 'Anatole France': np.float64(619.7110487410434), 'André Gide': np.float64(651.4443112965009), 'Charles Nodier': np.float64(604.4128177431353), 'François Mauriac': np.float64(605.6770216511627), 'George Sand': np.float64(722.2336352497239), 'Georges Bernanos': np.float64(696.445933425437), 'Gustave Flaubert': np.float64(616.0635559960574), 'Guy de Maupassant': np.float64(631.0571659287763), 'Henri Barbusse': np.float64(667.7516670843463), 'Honoré de Balzac': np.float64(715.0914517253198), 'Jules Renard': np.float64(678.6874240038693), 'Jules Vallès': np.float64(717.3739408543953), 'Jules Verne': np.float64(618.6950053393296), 'Marcel Proust': np.float64(799.8800566658549), 'Octave Mirbeau': np.float64(671.6365473213414), 'Paul Bourget': np.float64(717.0580809593835), 'Paul Féval': np.float64(699.3985347017021), 'Ponson du Terrail': np.float64(636.3457331392532), 'Prosper Mérimée': np.float64(660.4443042965386), 'Roger Martin du Gard': np.float64(707.0138610163003), 'Romain Rolland': np.float64(675.448300857213), 'Stendhal': np.float64(693.531386809794), 'Victor Hugo': np.float64(630.3646902645166), 'Émile Zola': np.float64(637.6110289219347)}
# Closest author: Charles Nodier (604.41), Target author (Prosper Mérimée): 660.44
# Delta to Prosper Mérimée: 660.44 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 2)
# Generated excerpt for Prosper Mérimée: Orso, pâle et frissonnant, se releva lentement, s’aidant de son fusil, dont la crosse s’enfonçait da...
# 1487 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(715.2326351522322), 'Alexandre Dumas': np.float64(700.2447882519955), 'Alfred de Vigny': np.float64(686.1500677850554), 'Alphonse Daudet': np.float64(665.3829265808324), 'Anatole France': np.float64(650.0180373852554), 'André Gide': np.float64(678.0091680849152), 'Charles Nodier': np.float64(640.9576713376252), 'François Mauriac': np.float64(624.0574812124376), 'George Sand': np.float64(730.7065329054335), 'Georges Bernanos': np.float64(667.4849570710861), 'Gustave Flaubert': np.float64(624.1317096601504), 'Guy de Maupassant': np.float64(664.5588181855746), 'Henri Barbusse': np.float64(673.8460384411245), 'Honoré de Balzac': np.float64(747.6796343914335), 'Jules Renard': np.float64(657.8933091244425), 'Jules Vallès': np.float64(757.5503965237169), 'Jules Verne': np.float64(666.331024893528), 'Marcel Proust': np.float64(848.9974641361746), 'Octave Mirbeau': np.float64(699.6094247069508), 'Paul Bourget': np.float64(739.5606562223505), 'Paul Féval': np.float64(718.6883921808351), 'Ponson du Terrail': np.float64(657.2353858476481), 'Prosper Mérimée': np.float64(650.9381719236701), 'Roger Martin du Gard': np.float64(710.2700816128183), 'Romain Rolland': np.float64(696.3729694829642), 'Stendhal': np.float64(741.6025289228312), 'Victor Hugo': np.float64(651.4645340393329), 'Émile Zola': np.float64(676.2501744805836)}
# Closest author: François Mauriac (624.06), Target author (Prosper Mérimée): 650.94
# Delta to Prosper Mérimée: 650.94 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 3)
# Generated excerpt for Prosper Mérimée: À ces paroles, les bergers s’entre-regardèrent, et un murmure de surprise courut dans le groupe. Le ...
# 1427 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(624.7692394772156), 'Alexandre Dumas': np.float64(643.9146170950585), 'Alfred de Vigny': np.float64(648.0931376284219), 'Alphonse Daudet': np.float64(602.7879069848135), 'Anatole France': np.float64(604.9324195502709), 'André Gide': np.float64(629.9470907763603), 'Charles Nodier': np.float64(578.3579493607411), 'François Mauriac': np.float64(577.8138053214554), 'George Sand': np.float64(670.8515271970293), 'Georges Bernanos': np.float64(612.3430529436237), 'Gustave Flaubert': np.float64(593.5737681600369), 'Guy de Maupassant': np.float64(619.6216826043838), 'Henri Barbusse': np.float64(651.7337975451179), 'Honoré de Balzac': np.float64(670.5455579707309), 'Jules Renard': np.float64(595.0656575818429), 'Jules Vallès': np.float64(698.880111976235), 'Jules Verne': np.float64(641.3816195013046), 'Marcel Proust': np.float64(782.3053537151061), 'Octave Mirbeau': np.float64(650.0245781973455), 'Paul Bourget': np.float64(700.1444275400884), 'Paul Féval': np.float64(654.7813521161705), 'Ponson du Terrail': np.float64(599.9324247066405), 'Prosper Mérimée': np.float64(619.5823911273515), 'Roger Martin du Gard': np.float64(670.3259970936172), 'Romain Rolland': np.float64(636.7056308049242), 'Stendhal': np.float64(692.3126156920043), 'Victor Hugo': np.float64(611.689570684623), 'Émile Zola': np.float64(630.6179272959357)}
# Closest author: François Mauriac (577.81), Target author (Prosper Mérimée): 619.58
# Delta to Prosper Mérimée: 619.58 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 4)
# Generated excerpt for Prosper Mérimée: Orso, étonné de voir sa sœur si pâle, la questionna du regard, mais elle détourna la tête, et, s’ass...
# 1603 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(640.576321535111), 'Alexandre Dumas': np.float64(649.2161330920011), 'Alfred de Vigny': np.float64(650.6612726090195), 'Alphonse Daudet': np.float64(640.9591097393486), 'Anatole France': np.float64(625.0349441035105), 'André Gide': np.float64(623.4634169035025), 'Charles Nodier': np.float64(595.5118917258069), 'François Mauriac': np.float64(589.8860523257871), 'George Sand': np.float64(666.6181592795781), 'Georges Bernanos': np.float64(633.9726736018731), 'Gustave Flaubert': np.float64(632.0131272614267), 'Guy de Maupassant': np.float64(651.4483738708443), 'Henri Barbusse': np.float64(657.3681461753649), 'Honoré de Balzac': np.float64(680.3704845462129), 'Jules Renard': np.float64(638.538532995491), 'Jules Vallès': np.float64(716.4552032639947), 'Jules Verne': np.float64(642.12874420301), 'Marcel Proust': np.float64(767.0414647950479), 'Octave Mirbeau': np.float64(655.9165410833198), 'Paul Bourget': np.float64(709.6108138756047), 'Paul Féval': np.float64(670.7372130963818), 'Ponson du Terrail': np.float64(627.7666909598554), 'Prosper Mérimée': np.float64(610.1051508720669), 'Roger Martin du Gard': np.float64(638.1797023316535), 'Romain Rolland': np.float64(646.9527121373058), 'Stendhal': np.float64(679.8520306725322), 'Victor Hugo': np.float64(642.2883492935257), 'Émile Zola': np.float64(663.377941366693)}
# Closest author: François Mauriac (589.89), Target author (Prosper Mérimée): 610.11
# Delta to Prosper Mérimée: 610.11 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 5)
# Generated excerpt for Prosper Mérimée: Orso, s’arrêtant près de sa sœur, contempla en silence le mucchio qui, malgré sa simplicité, frappai...
# 1574 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(710.4052146128607), 'Alexandre Dumas': np.float64(704.4405514512507), 'Alfred de Vigny': np.float64(703.0361461581219), 'Alphonse Daudet': np.float64(675.4049524325992), 'Anatole France': np.float64(667.7851221034148), 'André Gide': np.float64(680.0948464287058), 'Charles Nodier': np.float64(644.7450490990625), 'François Mauriac': np.float64(647.1733609099401), 'George Sand': np.float64(694.9495608353103), 'Georges Bernanos': np.float64(690.7517990156567), 'Gustave Flaubert': np.float64(670.8740189014095), 'Guy de Maupassant': np.float64(685.8532408589649), 'Henri Barbusse': np.float64(683.7619053457873), 'Honoré de Balzac': np.float64(718.8302318337659), 'Jules Renard': np.float64(684.6903879978142), 'Jules Vallès': np.float64(760.5524270308313), 'Jules Verne': np.float64(700.5318012301095), 'Marcel Proust': np.float64(834.7666026348603), 'Octave Mirbeau': np.float64(689.0017152401253), 'Paul Bourget': np.float64(738.949023403941), 'Paul Féval': np.float64(715.3076562506448), 'Ponson du Terrail': np.float64(681.9830145615008), 'Prosper Mérimée': np.float64(672.3778001283248), 'Roger Martin du Gard': np.float64(671.09319789017), 'Romain Rolland': np.float64(691.2645951613795), 'Stendhal': np.float64(735.1542325294479), 'Victor Hugo': np.float64(673.9760742683317), 'Émile Zola': np.float64(712.3737342106157)}
# Closest author: Charles Nodier (644.75), Target author (Prosper Mérimée): 672.38
# Delta to Prosper Mérimée: 672.38 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 6)
# Generated excerpt for Prosper Mérimée: Je n’osai m’aventurer sur le terrain glissant des souvenirs de Paris, et me contentai de sourire ave...
# 1505 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(614.6106406426707), 'Alexandre Dumas': np.float64(625.5417706762964), 'Alfred de Vigny': np.float64(662.1684584668761), 'Alphonse Daudet': np.float64(583.8021988996683), 'Anatole France': np.float64(576.666728357588), 'André Gide': np.float64(615.1264928944747), 'Charles Nodier': np.float64(586.7295017759616), 'François Mauriac': np.float64(575.8855662733804), 'George Sand': np.float64(664.3060037993487), 'Georges Bernanos': np.float64(674.608828437064), 'Gustave Flaubert': np.float64(592.5850143018322), 'Guy de Maupassant': np.float64(610.4528615929275), 'Henri Barbusse': np.float64(671.6982487674604), 'Honoré de Balzac': np.float64(679.5738157427647), 'Jules Renard': np.float64(643.5338597533148), 'Jules Vallès': np.float64(686.3460042991821), 'Jules Verne': np.float64(607.0374025540224), 'Marcel Proust': np.float64(714.064498419541), 'Octave Mirbeau': np.float64(639.0051861417511), 'Paul Bourget': np.float64(684.7074908391457), 'Paul Féval': np.float64(652.6873311929237), 'Ponson du Terrail': np.float64(619.9979077957267), 'Prosper Mérimée': np.float64(615.3449528029003), 'Roger Martin du Gard': np.float64(705.0234940649239), 'Romain Rolland': np.float64(635.7279876228383), 'Stendhal': np.float64(656.3003184178174), 'Victor Hugo': np.float64(608.103130505961), 'Émile Zola': np.float64(614.6127840330582)}
# Closest author: François Mauriac (575.89), Target author (Prosper Mérimée): 615.34
# Delta to Prosper Mérimée: 615.34 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 7)
# Generated excerpt for Prosper Mérimée: — Sans doute, répondis-je, Adonis, ou plutôt Mars, selon la fable.
#
# — Eh bien! reprit M. de Peyrehor...
# 1558 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(643.716180569045), 'Alexandre Dumas': np.float64(632.752609726869), 'Alfred de Vigny': np.float64(641.6838957476049), 'Alphonse Daudet': np.float64(610.3494452053143), 'Anatole France': np.float64(594.3541834663675), 'André Gide': np.float64(631.6607717341852), 'Charles Nodier': np.float64(604.6288658606935), 'François Mauriac': np.float64(634.0472236938452), 'George Sand': np.float64(662.4056829591311), 'Georges Bernanos': np.float64(649.3065081626622), 'Gustave Flaubert': np.float64(629.7814967966403), 'Guy de Maupassant': np.float64(642.0684819265721), 'Henri Barbusse': np.float64(630.9711547886288), 'Honoré de Balzac': np.float64(660.8064472554356), 'Jules Renard': np.float64(630.7105288229823), 'Jules Vallès': np.float64(684.3063423784903), 'Jules Verne': np.float64(624.9476065180431), 'Marcel Proust': np.float64(775.5086573259794), 'Octave Mirbeau': np.float64(615.0638896080383), 'Paul Bourget': np.float64(685.5558105254016), 'Paul Féval': np.float64(630.0078514886911), 'Ponson du Terrail': np.float64(621.253537168745), 'Prosper Mérimée': np.float64(614.3311486948265), 'Roger Martin du Gard': np.float64(652.0673290751349), 'Romain Rolland': np.float64(682.6668909455534), 'Stendhal': np.float64(687.8341730104124), 'Victor Hugo': np.float64(592.3192435286849), 'Émile Zola': np.float64(667.5236121564615)}
# Closest author: Victor Hugo (592.32), Target author (Prosper Mérimée): 614.33
# Delta to Prosper Mérimée: 614.33 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 8)
# Generated excerpt for Prosper Mérimée: Orso, touché de ce témoignage d'intérêt, ne trouva d'abord rien à répondre ; il serra la main que mi...
# 1514 tokens in generated excerpt
# ...
# Closest author: François Mauriac (626.60), Target author (Prosper Mérimée): 674.34
# Delta to Prosper Mérimée: 674.34 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 34)
# Generated excerpt for Prosper Mérimée: Cependant, Orso, lancé à toute bride, sentit bientôt s’apaiser en lui la première ardeur de la colèr...
# 1542 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(643.1548645750618), 'Alexandre Dumas': np.float64(642.6910115987614), 'Alfred de Vigny': np.float64(614.5740741073233), 'Alphonse Daudet': np.float64(584.7764873638273), 'Anatole France': np.float64(560.0614991220805), 'André Gide': np.float64(617.4777763095201), 'Charles Nodier': np.float64(566.7525386918551), 'François Mauriac': np.float64(563.8772595336343), 'George Sand': np.float64(637.5095812755154), 'Georges Bernanos': np.float64(638.8496110205168), 'Gustave Flaubert': np.float64(576.3808263344804), 'Guy de Maupassant': np.float64(595.8005580138364), 'Henri Barbusse': np.float64(650.0620840978687), 'Honoré de Balzac': np.float64(625.3077012862761), 'Jules Renard': np.float64(625.9567723608887), 'Jules Vallès': np.float64(679.4003313288335), 'Jules Verne': np.float64(599.4186954704985), 'Marcel Proust': np.float64(731.0639886337328), 'Octave Mirbeau': np.float64(622.314532327978), 'Paul Bourget': np.float64(646.5914857587497), 'Paul Féval': np.float64(649.8551213485362), 'Ponson du Terrail': np.float64(608.6994715013864), 'Prosper Mérimée': np.float64(587.9447433723205), 'Roger Martin du Gard': np.float64(644.6671834406498), 'Romain Rolland': np.float64(613.590625021852), 'Stendhal': np.float64(639.4574488644212), 'Victor Hugo': np.float64(600.5524210847794), 'Émile Zola': np.float64(623.9246581924294)}
# Closest author: Anatole France (560.06), Target author (Prosper Mérimée): 587.94
# Delta to Prosper Mérimée: 587.94 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 35)
# Generated excerpt for Prosper Mérimée: Aucun des bergers ne bougea d’abord. Ils échangèrent entre eux quelques regards d’intelligence, comm...
# 1545 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(699.0723557126339), 'Alexandre Dumas': np.float64(695.3738704905456), 'Alfred de Vigny': np.float64(705.4338584028915), 'Alphonse Daudet': np.float64(663.8679915243388), 'Anatole France': np.float64(659.6317183909288), 'André Gide': np.float64(713.8265113006196), 'Charles Nodier': np.float64(648.4691270292765), 'François Mauriac': np.float64(660.7382761803957), 'George Sand': np.float64(759.2034850914954), 'Georges Bernanos': np.float64(706.7568835299055), 'Gustave Flaubert': np.float64(635.4167459011458), 'Guy de Maupassant': np.float64(669.1188176414396), 'Henri Barbusse': np.float64(697.2143932915667), 'Honoré de Balzac': np.float64(758.0475046119748), 'Jules Renard': np.float64(693.8125837740713), 'Jules Vallès': np.float64(762.0760495230045), 'Jules Verne': np.float64(677.4769250815078), 'Marcel Proust': np.float64(847.1736252842243), 'Octave Mirbeau': np.float64(720.0785429133051), 'Paul Bourget': np.float64(765.2274736591744), 'Paul Féval': np.float64(728.8720765797876), 'Ponson du Terrail': np.float64(683.2039025314152), 'Prosper Mérimée': np.float64(676.1155283174191), 'Roger Martin du Gard': np.float64(734.5689894716335), 'Romain Rolland': np.float64(709.7713036245061), 'Stendhal': np.float64(758.6067843860362), 'Victor Hugo': np.float64(683.8764375830233), 'Émile Zola': np.float64(689.5454759748072)}
# Closest author: Gustave Flaubert (635.42), Target author (Prosper Mérimée): 676.12
# Delta to Prosper Mérimée: 676.12 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 36)
# Generated excerpt for Prosper Mérimée: Orso resta un moment interdit, le regard fixé sur le préfet, comme s’il doutait d’avoir bien compris...
# 1327 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(662.6464634106908), 'Alexandre Dumas': np.float64(657.6765735110146), 'Alfred de Vigny': np.float64(659.4977877014684), 'Alphonse Daudet': np.float64(644.5239276942245), 'Anatole France': np.float64(611.0271646764558), 'André Gide': np.float64(614.9179242875853), 'Charles Nodier': np.float64(602.177952577374), 'François Mauriac': np.float64(588.1309057148646), 'George Sand': np.float64(669.4334741393078), 'Georges Bernanos': np.float64(612.2297127701386), 'Gustave Flaubert': np.float64(651.3054707959186), 'Guy de Maupassant': np.float64(659.3238575755578), 'Henri Barbusse': np.float64(685.5055385178096), 'Honoré de Balzac': np.float64(695.1085015464303), 'Jules Renard': np.float64(634.197688924532), 'Jules Vallès': np.float64(722.0271747668326), 'Jules Verne': np.float64(632.961718115894), 'Marcel Proust': np.float64(773.675030221309), 'Octave Mirbeau': np.float64(657.298616104148), 'Paul Bourget': np.float64(691.4413987591961), 'Paul Féval': np.float64(670.7641869085505), 'Ponson du Terrail': np.float64(624.8900542288275), 'Prosper Mérimée': np.float64(639.0956497837938), 'Roger Martin du Gard': np.float64(628.5201930921597), 'Romain Rolland': np.float64(648.1101698581962), 'Stendhal': np.float64(683.6699939782018), 'Victor Hugo': np.float64(644.2095946892921), 'Émile Zola': np.float64(670.748958082778)}
# Closest author: François Mauriac (588.13), Target author (Prosper Mérimée): 639.10
# Delta to Prosper Mérimée: 639.10 | 90th percentile: 644.17
# Excerpt length OK: False, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 37)
# Generated excerpt for Prosper Mérimée: Orso, touché de ce ton plus doux, sentit s’évanouir la froideur qu’il avait gardée depuis la veille....
# 1523 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(614.0551239869421), 'Alexandre Dumas': np.float64(661.6157230792526), 'Alfred de Vigny': np.float64(674.9100495751795), 'Alphonse Daudet': np.float64(602.3470538971203), 'Anatole France': np.float64(624.5991539935338), 'André Gide': np.float64(636.3470115148866), 'Charles Nodier': np.float64(641.8769474957979), 'François Mauriac': np.float64(578.7541106910294), 'George Sand': np.float64(704.4194303543558), 'Georges Bernanos': np.float64(645.0353903700852), 'Gustave Flaubert': np.float64(605.3018954950591), 'Guy de Maupassant': np.float64(623.4987320041678), 'Henri Barbusse': np.float64(658.0477582680256), 'Honoré de Balzac': np.float64(700.0028174660752), 'Jules Renard': np.float64(651.8263611739786), 'Jules Vallès': np.float64(718.4290429861043), 'Jules Verne': np.float64(649.9987938578677), 'Marcel Proust': np.float64(798.5334288105689), 'Octave Mirbeau': np.float64(664.4326897218868), 'Paul Bourget': np.float64(690.2906338012519), 'Paul Féval': np.float64(687.2450055492974), 'Ponson du Terrail': np.float64(623.6939919279936), 'Prosper Mérimée': np.float64(631.8363832097348), 'Roger Martin du Gard': np.float64(684.0708467060616), 'Romain Rolland': np.float64(662.5698571243831), 'Stendhal': np.float64(688.5199523048389), 'Victor Hugo': np.float64(636.8121883791833), 'Émile Zola': np.float64(632.427941430925)}
# Closest author: François Mauriac (578.75), Target author (Prosper Mérimée): 631.84
# Delta to Prosper Mérimée: 631.84 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 38)
# Generated excerpt for Prosper Mérimée: Orso, en franchissant le seuil de la maison paternelle, éprouva ce malaise particulier qu’on ressent...
# 1529 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(682.5388733517113), 'Alexandre Dumas': np.float64(692.2614272931746), 'Alfred de Vigny': np.float64(711.9475172387663), 'Alphonse Daudet': np.float64(638.659134959365), 'Anatole France': np.float64(617.8587875508042), 'André Gide': np.float64(680.8018915093014), 'Charles Nodier': np.float64(629.2067351517345), 'François Mauriac': np.float64(604.6261211008205), 'George Sand': np.float64(737.8038545175727), 'Georges Bernanos': np.float64(724.9316476773721), 'Gustave Flaubert': np.float64(617.2577992706781), 'Guy de Maupassant': np.float64(654.9970416697873), 'Henri Barbusse': np.float64(693.7172135938447), 'Honoré de Balzac': np.float64(734.3944092420995), 'Jules Renard': np.float64(706.4608597147433), 'Jules Vallès': np.float64(759.145643047249), 'Jules Verne': np.float64(666.4163484968387), 'Marcel Proust': np.float64(827.2541311007508), 'Octave Mirbeau': np.float64(692.846957195276), 'Paul Bourget': np.float64(758.1729923544495), 'Paul Féval': np.float64(733.9259493156385), 'Ponson du Terrail': np.float64(677.4999016044117), 'Prosper Mérimée': np.float64(670.7490594960499), 'Roger Martin du Gard': np.float64(738.1498166513197), 'Romain Rolland': np.float64(658.5063031551467), 'Stendhal': np.float64(727.9314879207623), 'Victor Hugo': np.float64(661.2464845748647), 'Émile Zola': np.float64(683.3109168716314)}
# Closest author: François Mauriac (604.63), Target author (Prosper Mérimée): 670.75
# Delta to Prosper Mérimée: 670.75 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 39)
# Generated excerpt for Prosper Mérimée: — Mars, sans doute, répondis-je, et, pour les poètes, il n’a pas été heureux dans sa passion.
#
# — Oui...
# 1587 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(622.7818989685611), 'Alexandre Dumas': np.float64(643.5193692194907), 'Alfred de Vigny': np.float64(635.2385164155429), 'Alphonse Daudet': np.float64(614.4837310807179), 'Anatole France': np.float64(606.2671410446787), 'André Gide': np.float64(589.4804942559471), 'Charles Nodier': np.float64(619.038038261943), 'François Mauriac': np.float64(620.3487726676301), 'George Sand': np.float64(621.7023233969267), 'Georges Bernanos': np.float64(667.3277856625472), 'Gustave Flaubert': np.float64(650.7695560180969), 'Guy de Maupassant': np.float64(647.2200799178208), 'Henri Barbusse': np.float64(644.8844938282508), 'Honoré de Balzac': np.float64(651.920727602349), 'Jules Renard': np.float64(635.6533625906756), 'Jules Vallès': np.float64(651.4736408669551), 'Jules Verne': np.float64(653.2762092493637), 'Marcel Proust': np.float64(712.776130171052), 'Octave Mirbeau': np.float64(608.1355209625556), 'Paul Bourget': np.float64(672.1837733640893), 'Paul Féval': np.float64(640.9487451698541), 'Ponson du Terrail': np.float64(628.5383712481027), 'Prosper Mérimée': np.float64(601.5385339810357), 'Roger Martin du Gard': np.float64(649.9372229884968), 'Romain Rolland': np.float64(654.2706562072133), 'Stendhal': np.float64(683.3072953723206), 'Victor Hugo': np.float64(633.5895593402221), 'Émile Zola': np.float64(671.2496588181782)}
# Closest author: André Gide (589.48), Target author (Prosper Mérimée): 601.54
# Delta to Prosper Mérimée: 601.54 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 40)
# Generated excerpt for Prosper Mérimée: Les débats judiciaires, ainsi obscurcis par le manque de preuves et la contradiction des témoignages...
# 1424 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(668.8318630046814), 'Alexandre Dumas': np.float64(679.1554131511837), 'Alfred de Vigny': np.float64(680.1599166857026), 'Alphonse Daudet': np.float64(634.0814722197938), 'Anatole France': np.float64(604.1348888340524), 'André Gide': np.float64(649.8074315853127), 'Charles Nodier': np.float64(594.1356984830666), 'François Mauriac': np.float64(583.5748521671255), 'George Sand': np.float64(705.3024033208915), 'Georges Bernanos': np.float64(678.8290565805019), 'Gustave Flaubert': np.float64(626.9880225096008), 'Guy de Maupassant': np.float64(628.4727016438976), 'Henri Barbusse': np.float64(693.8064017184233), 'Honoré de Balzac': np.float64(692.3742391235742), 'Jules Renard': np.float64(693.9571891832082), 'Jules Vallès': np.float64(732.0490443890578), 'Jules Verne': np.float64(665.09623673466), 'Marcel Proust': np.float64(789.9392444214474), 'Octave Mirbeau': np.float64(663.1594490738854), 'Paul Bourget': np.float64(707.3254901858204), 'Paul Féval': np.float64(694.191144283504), 'Ponson du Terrail': np.float64(652.0265452846717), 'Prosper Mérimée': np.float64(662.2977169632152), 'Roger Martin du Gard': np.float64(709.9103522975716), 'Romain Rolland': np.float64(648.3651645961754), 'Stendhal': np.float64(687.2660540127217), 'Victor Hugo': np.float64(642.4544509632901), 'Émile Zola': np.float64(644.8882997833421)}
# Closest author: François Mauriac (583.57), Target author (Prosper Mérimée): 662.30
# Delta to Prosper Mérimée: 662.30 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 41)
# Generated excerpt for Prosper Mérimée: Orso, étonné de ce calme apparent et de la réserve de sa sœur, se promena dans la salle basse, jetan...
# 1558 tokens in generated excerpt
# Delta scores for Prosper Mérimée: {'Alain-Fournier': np.float64(677.5553042974052), 'Alexandre Dumas': np.float64(653.0676902764085), 'Alfred de Vigny': np.float64(676.5050530987321), 'Alphonse Daudet': np.float64(656.3796546205842), 'Anatole France': np.float64(664.6093754008905), 'André Gide': np.float64(628.0688444129722), 'Charles Nodier': np.float64(639.6237467479468), 'François Mauriac': np.float64(604.9158262281128), 'George Sand': np.float64(700.2676425780934), 'Georges Bernanos': np.float64(654.4092708293009), 'Gustave Flaubert': np.float64(653.9411645645845), 'Guy de Maupassant': np.float64(673.745847285389), 'Henri Barbusse': np.float64(675.0932085260404), 'Honoré de Balzac': np.float64(713.8393744587609), 'Jules Renard': np.float64(676.039705796515), 'Jules Vallès': np.float64(729.7837442671474), 'Jules Verne': np.float64(693.1564262296531), 'Marcel Proust': np.float64(801.3666132308233), 'Octave Mirbeau': np.float64(673.5588881966867), 'Paul Bourget': np.float64(693.2103497900999), 'Paul Féval': np.float64(686.9174616197218), 'Ponson du Terrail': np.float64(622.5480289537385), 'Prosper Mérimée': np.float64(640.4825025431834), 'Roger Martin du Gard': np.float64(662.1005131583905), 'Romain Rolland': np.float64(694.4950212863132), 'Stendhal': np.float64(706.8261657622095), 'Victor Hugo': np.float64(657.7845453464704), 'Émile Zola': np.float64(666.2620445831091)}
# Closest author: François Mauriac (604.92), Target author (Prosper Mérimée): 640.48
# Delta to Prosper Mérimée: 640.48 | 90th percentile: 644.17
# Excerpt length OK: True, Good style: False
# Generating excerpt for Prosper Mérimée... (Attempt 42)

# %%
# df . sample et gen ID à checker
